# %%
import mysql.connector
import os
from dotenv import load_dotenv

load_dotenv("/home/jovyan/work/.env")

conn = mysql.connector.connect(
    host=os.getenv("DB_HOST"),
    port=int(os.getenv("DB_PORT")),
    database=os.getenv("DB_NAME"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD")
)

# %%
with open("/home/jovyan/work/sql/creacion_indices.sql", "r", encoding="utf-8") as f:
    indices = f.read()

# %%
cursor = conn.cursor()

for i, statement in enumerate(indices.split(";")):
    stmt = statement.strip()

    if stmt:
        try:
            print(f"\nEjecutando statement {i}")
            cursor.execute(stmt)
        except Exception as e:
            print("\nERROR EN:")
            print(stmt)
            print("\nMENSAJE:")
            print(e)
            break

conn.commit()

print("\nSchema ejecutado correctamente")
# Out:
# Ejecutando statement 0
#
# Ejecutando statement 1
#
# Ejecutando statement 2
#
# Ejecutando statement 3
#
# Ejecutando statement 4
#
# Schema ejecutado correctamente
