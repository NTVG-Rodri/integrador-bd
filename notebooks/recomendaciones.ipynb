# %%
import sys
sys.path.append("/home/jovyan/work")
import src.configuracion_ia as cia

# %%
cia.obtener_recomendaciones_ia(0)
# Out:
#   titulo autor genero                                             motivo
# 0                      El socio no posee historial suficiente para ge...
