# %%
import mysql.connector
import os
from dotenv import load_dotenv

load_dotenv("/home/jovyan/work/.env")

conn = mysql.connector.connect(
    host=os.getenv("DB_HOST"),
    port=int(os.getenv("DB_PORT")),
    database=os.getenv("DB_NAME"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD")
)

# %%
with open("/home/jovyan/work/sql/data.sql", "r", encoding="utf-8") as f:
    data = f.read()

# %%
cursor = conn.cursor()

for i, statement in enumerate(data.split(";")):
    stmt = statement.strip()

    if stmt:
        try:
            print(f"\nEjecutando statement {i}")
            cursor.execute(stmt)
        except Exception as e:
            print("\nERROR EN:")
            print(stmt)
            print("\nMENSAJE:")
            print(e)
            break

conn.commit()

print("\nSchema ejecutado correctamente")
# Out:
# Ejecutando statement 0
#
# Ejecutando statement 1
#
# Ejecutando statement 2
#
# Ejecutando statement 3
#
# Ejecutando statement 4
#
# Ejecutando statement 5
#
# Ejecutando statement 6
#
# Ejecutando statement 7
#
# Ejecutando statement 8
#
# Ejecutando statement 9
#
# Ejecutando statement 10
#
# Ejecutando statement 11
#
# Ejecutando statement 12
#
# Ejecutando statement 13
#
# Ejecutando statement 14
#
# Ejecutando statement 15
#
# Ejecutando statement 16
#
# Ejecutando statement 17
#
# Ejecutando statement 18
#
# Ejecutando statement 19
#
# Ejecutando statement 20
#
# Ejecutando statement 21
#
# Ejecutando statement 22
#
# Ejecutando statement 23
#
# Ejecutando statement 24
#
# Ejecutando statement 25
#
# Ejecutando statement 26
#
# Ejecutando statement 27
#
# Ejecutando statement 28
#
# Ejecutando statement 29
#
# Ejecutando statement 30
#
# Ejecutando statement 31
#
# Ejecutando statement 32
#
# Ejecutando statement 33
#
# Ejecutando statement 34
#
# Ejecutando statement 35
#
# Ejecutando statement 36
#
# Ejecutando statement 37
#
# Ejecutando statement 38
#
# Ejecutando statement 39
#
# Ejecutando statement 40
#
# Ejecutando statement 41
#
# Ejecutando statement 42
#
# Ejecutando statement 43
#
# Ejecutando statement 44
#
# Ejecutando statement 45
#
# Ejecutando statement 46
#
# Ejecutando statement 47
#
# Ejecutando statement 48
#
# Ejecutando statement 49
#
# Ejecutando statement 50
#
# Ejecutando statement 51
#
# Ejecutando statement 52
#
# Ejecutando statement 53
#
# Schema ejecutado correctamente
